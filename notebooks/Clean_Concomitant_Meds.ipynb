# %% [markdown]
# # How to clean Concomitant Meds
#
# This notebook demonstrates how to load and clean the concomitant medication table from the PPMI dataset. It finishes by building a pivot table of comorbidities for each patient, determined by whether the patient was ever on medication for one of the labelled comorbidities.

# %%
import pandas as pd
import pie_clean

# %%
# Load data, and check we have the Concomitant Meds
# For demonstration purposes, we will not automatically clean the data upon loading
data = pie_clean.DataLoader.load("../PPMI", clean_data=False)
cmeds_df = data[pie_clean.MEDICAL_HISTORY]["Concomitant_Medication"]
print(cmeds_df.shape)
cmeds_df.head()
# Out:
# 2025-10-10 09:08:30 data_loader.py [INFO] Biospecimen modality requested. Exclusion list: []
# 2025-10-10 09:08:30 data_loader.py [INFO] Loading subject_characteristics data...
# 2025-10-10 09:08:30 sub_char_loader.py [INFO] Subject Characteristics: Consolidating rows with duplicate (PATNO, EVENT_ID) pairs. Non-null values for other columns will be pipe-separated if different.
# 2025-10-10 09:08:30 sub_char_loader.py [INFO] Summary of pipe-separated columns for Subject Characteristics:
# 2025-10-10 09:08:30 sub_char_loader.py [INFO]   - Column 'AGE_AT_VISIT': 171 groups had multiple values.
# 2025-10-10 09:08:30 sub_char_loader.py [INFO]     - Example for group ('100232', 'V04'): values were ['65.2', '65.4']
# 2025-10-10 09:08:30 sub_char_loader.py [INFO] Final loaded subject characteristics shape: (36420, 29)
# 2025-10-10 09:08:30 data_loader.py [INFO] Loaded subject_characteristics with 36420 rows
# /Users/vic/Projects/MJFF/PIE-clean/pie_clean/sub_char_loader.py:196: PerformanceWarning: indexing past lexsort depth may impact performance.
#   conflicting_values = df_indexed.loc[first_offending_group_index, col].dropna().astype(str).unique()
# 2025-10-10 09:08:32 data_loader.py [INFO] Loading medical_history data...
# 2025-10-10 09:08:32 med_hist_loader.py [WARNING] No CSV file found for prefix: Adverse_Event
# 2025-10-10 09:08:32 med_hist_loader.py [WARNING] No CSV file found for prefix: AV-133_Prodromal
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: C05-05_PET_Imaging_Substudy
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Clinical_Diagnosis
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Clinical_Global_Impression
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Determination_of_Freezing_and_Falls
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: DPA-714_PET_Imaging_Substudy_Adverse_Event
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Early_Imaging
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Features_of_REM_Behavior_Disorder
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Gait_Substudy_Adverse_Event
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Initiation_of_Dopaminergic_Therapy
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Medical_Conditions
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Neurological_Exam
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Other_Clinical_Features
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Participant_Global_Impression
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: PD_Diagnosis_History
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Pregnancy_Test
# /Users/vic/Projects/MJFF/PIE-clean/pie_clean/med_hist_loader.py:142: DtypeWarning: Columns (6,7,13,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(csv_file)
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Primary_Clincial_Diagnosis
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Procedure_for_PD_Log
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Report_of_Pregnancy
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: SVA2_PET_Imaging_Substudy
# 2025-10-10 09:08:33 med_hist_loader.py [WARNING] No CSV file found for prefix: Tau_Substudy
# 2025-10-10 09:08:33 data_loader.py [INFO] Loaded 5 medical_history tables
# 2025-10-10 09:08:41 data_loader.py [INFO] Loading motor_assessments data...
# 2025-10-10 09:08:41 data_loader.py [WARNING] Directory not found: ../PPMI/Motor___MDS-UPDRS
# 2025-10-10 09:08:41 data_loader.py [INFO] Loading non_motor_assessments data...
# 2025-10-10 09:08:41 data_loader.py [WARNING] Directory not found: ../PPMI/Non-motor_Assessments
# 2025-10-10 09:08:41 data_loader.py [INFO] Loading biospecimen data...
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No non-batch-corrected Project_151_pQTL_in_CSF files found in ../PPMI/Biospecimen
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded Project_151_pQTL_in_CSF data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No batch-corrected Project_151_pQTL_in_CSF files found in ../PPMI/Biospecimen
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded batch-corrected Project_151_pQTL_in_CSF data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No Metabolomic_Analysis_of_LRRK2 files found in ../PPMI/Biospecimen (excluding CSF files)
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded Metabolomic_Analysis_of_LRRK2 data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No Metabolomic_Analysis_of_LRRK2 files found in ../PPMI/Biospecimen (including CSF files)
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded Metabolomic_Analysis_of_LRRK2_CSF data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No Targeted___untargeted_MS-based_proteomics_of_urine_in_PD files found in ../PPMI/Biospecimen
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded urine proteomics data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No PPMI_Project_9000 files found in ../PPMI/Biospecimen
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded Project 9000 data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No PPMI_Project_222 files found in ../PPMI/Biospecimen
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded Project 222 data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No PPMI_Project_196 files found in ../PPMI/Biospecimen
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded Project 196 data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No PPMI_Project_177 files found in ../PPMI/Biospecimen
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded Project 177 data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [WARNING] No Project_214_Olink files found in ../PPMI/Biospecimen
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loaded Project 214 data: 0 rows
# 2025-10-10 09:08:41 biospecimen_loader.py [INFO] Loading file: ../PPMI/Biospecimen/Current_Biospecimen_Analysis_Results_13Jun2025.csv
# /Users/vic/Projects/MJFF/PIE-clean/pie_clean/biospecimen_loader.py:1296: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# 2025-10-10 09:08:50 biospecimen_loader.py [INFO] Successfully processed Current Biospecimen Analysis data: 9368 rows, 4782 columns
# 2025-10-10 09:08:50 biospecimen_loader.py [INFO] Loaded Current Biospecimen Analysis data: 9368 rows
# 2025-10-10 09:08:50 biospecimen_loader.py [WARNING] No Blood_Chemistry___Hematology files found in ../PPMI/Biospecimen
# 2025-10-10 09:08:50 biospecimen_loader.py [INFO] Loaded Blood Chemistry & Hematology data: 0 rows
# 2025-10-10 09:08:50 biospecimen_loader.py [WARNING] No files matching the provided prefixes found in ../PPMI/Biospecimen
# 2025-10-10 09:08:50 biospecimen_loader.py [INFO] Loaded standard biospecimen files: 0 rows
# 2025-10-10 09:08:50 biospecimen_loader.py [INFO] Using all available data sources
# 2025-10-10 09:08:50 biospecimen_loader.py [INFO] Processing 13 data sources: ['project_151_pQTL_CSF', 'project_151_pQTL_CSF_batch_corrected', 'metabolomic_lrrk2', 'metabolomic_lrrk2_csf', 'urine_proteomics', 'project_9000', 'project_222', 'project_196', 'project_177', 'project_214', 'current_biospecimen', 'blood_chemistry_hematology', 'standard_files']
# 2025-10-10 09:08:50 biospecimen_loader.py [INFO] Memory usage (start of merge_biospecimen_data): 627.19 MB
# 2025-10-10 09:08:50 biospecimen_loader.py [INFO] Merging filtered biospecimen data into a single DataFrame
# 2025-10-10 09:08:52 biospecimen_loader.py [INFO] Created base DataFrame for biospecimen merge with 9368 unique PATNO/EVENT_ID pairs
# 2025-10-10 09:08:52 biospecimen_loader.py [INFO] Memory usage (biospecimen base_df created): 972.43 MB
# 2025-10-10 09:08:52 biospecimen_loader.py [INFO] Merging current_biospecimen (9368 rows, 4782 total cols) into main biospecimen DataFrame
# 2025-10-10 09:08:54 biospecimen_loader.py [INFO] Memory usage (after merging current_biospecimen): 1219.91 MB
# 2025-10-10 09:08:54 biospecimen_loader.py [INFO] Performing final aggregation on the fully merged biospecimen DataFrame...
# 2025-10-10 09:08:55 biospecimen_loader.py [INFO] Final merged biospecimen DataFrame: 9368 rows, 4782 columns
# 2025-10-10 09:08:55 biospecimen_loader.py [INFO] Confirmed: Final merged biospecimen DataFrame has unique (PATNO, EVENT_ID) pairs.
# 2025-10-10 09:08:55 biospecimen_loader.py [INFO] Data contribution from each source (post-internal aggregation):
# 2025-10-10 09:08:55 biospecimen_loader.py [INFO]   current_biospecimen: 9368 rows, 4780 data columns
# 2025-10-10 09:08:55 biospecimen_loader.py [INFO] Memory usage (end of merge_biospecimen_data (merged)): 1207.57 MB
# 2025-10-10 09:08:56 data_loader.py [INFO] Loaded biospecimen data
# (45267, 22)
#       REC_ID  PATNO EVENT_ID PAG_NAME                CMTRT  CMDOSE CMDOSU  \
# 0     IA9331   3000       ED   CONMED           Lisinopril     NaN    NaN
# 1  412285501   3000      LOG     CMED            MELATONIN     3.0     MG
# 2  627733901   3000      LOG     CMED            PNEUMOVAX    25.0    MCG
# 3  269586901   3000      LOG     CMED           LISINOPRIL    20.0     MG
# 4  269587001   3000      LOG     CMED  HYDROCHLOROTHIAZIDE    25.0     MG
#
#   CMDOSFRQ  ROUTE  STARTDT  ... CMINDC         CMINDC_TEXT  TOTDDOSE    RECNO  \
# 0      NaN    NaN  01/2016  ...   14.0                 NaN       NaN      NaN
# 1      PRN    3.0  04/2013  ...    NaN            INSOMNIA       NaN  12432.0
# 2     ONCE    2.0  02/2017  ...    NaN  AT RISK POPULATION       NaN   4966.0
# 3       QD    3.0  01/2006  ...    NaN        HYPERTENSION       NaN   8940.0
# 4       QD    3.0  01/2006  ...    NaN        HYPERTENSION       NaN    220.0
#
#    SEQNO1  SEQNO2              WHODRUG  EXCLMED ORIG_ENTRY  \
# 0     NaN     NaN                  NaN      NaN    06/2021
# 1     1.0     1.0            MELATONIN        N    09/2013
# 2     1.0     2.0            PNEUMOVAX        N    04/2017
# 3     1.0     1.0           LISINOPRIL        N    01/2011
# 4     1.0     1.0  HYDROCHLOROTHIAZIDE        N    01/2011
#
#              LAST_UPDATE
# 0  2022-11-07 00:00:00.0
# 1  2020-06-25 16:02:20.0
# 2  2020-06-25 16:02:20.0
# 3  2022-09-13 07:29:02.0
# 4  2022-09-13 07:29:02.0
#
# [5 rows x 22 columns]

# %%
# Before cleaning, check the dtypes of the dates
print(cmeds_df["STARTDT"].dtype)
print(cmeds_df["STOPDT"].dtype)
# Out:
# object
# object

# %%
# Before cleaning, count how many indication codes we have (45267 rows but fewer codes)
print(f"There are {cmeds_df['CMINDC'].isnull().sum()} nulls")
cmeds_df["CMINDC"].value_counts()
# Out:
# There are 19514 nulls
# CMINDC
# 25.0    8728
# 24.0    2636
# 14.0    2558
# 22.0    2020
# 13.0    1679
# 10.0    1168
# 17.0     821
# 12.0     747
# 1.0      686
# 11.0     685
# 3.0      648
# 23.0     602
# 15.0     563
# 18.0     528
# 6.0      477
# 7.0      441
# 20.0     220
# 2.0      207
# 19.0     119
# 4.0       69
# 5.0       69
# 16.0      39
# 9.0       24
# 8.0       14
# 21.0       5
# Name: count, dtype: int64

# %%
# Clean up the dates, and map the indication codes and reason text
clean_df = pie_clean.DataPreprocessor.clean_concomitant_meds(cmeds_df)
# Out:
# 2025-10-10 09:09:34 data_preprocessor.py [INFO] There are 78 concomitant medication entries with no start date.
# 2025-10-10 09:09:34 data_preprocessor.py [INFO] There are 21696 concomitant medication entries with no stop date.

# %%
# After cleaning, dates are now datetimes
print(clean_df["STARTDT"].dtype)
print(clean_df["STOPDT"].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %%
# After cleaning, all indication codes have been mapped, and converted to int
print(f"There are {clean_df['CMINDC'].isnull().sum()} nulls")
clean_df["CMINDC"].value_counts()
# Out:
# There are 0 nulls
# CMINDC
# 25    13142
# 24     5080
# 22     4877
# 14     4110
# 13     2588
# 17     2554
# 10     2001
# 23     1456
# 12     1264
# 1      1166
# 3      1131
# 15     1083
# 11      987
# 6       896
# 18      686
# 7       648
# 20      419
# 2       361
# 4       199
# 19      171
# 8       130
# 16      129
# 5        90
# 9        84
# 21       15
# Name: count, dtype: int64

# %%
# We can look at the text instead of the codes
clean_df["CMINDC_TEXT"].value_counts()
# Out:
# CMINDC_TEXT
# Other                                                         13142
# Vitamins / Coenzymes                                           5080
# Supplements / Homeopathic Medication                           4877
# Hypertension                                                   4110
# Hyperlipidemia                                                 2588
# Pain                                                           2554
# Depression                                                     2001
# Thyroid Disorder                                               1456
# GERD                                                           1264
# Anxiety                                                        1166
# Benign Prostatic Hypertrophy / Overactive Bladder              1131
# Insomnia                                                       1083
# Diabetes                                                        987
# Constipation                                                    896
# REM-Behavior Disorder                                           686
# Coronary Artery Disease, Peripheral Artery Disease, Stroke      648
# Sexual Dysfunction                                              419
# Atrial Fibrillation / Arrhythmias                               361
# Cognitive Dysfunction                                           199
# Restless Leg Syndrome                                           171
# Daytime Sleepiness                                              130
# Nausea                                                          129
# Congestive Heart Failure                                         90
# Delusions, Hallucination, Psychosis                              84
# Sialorrhea / Drooling                                            15
# Name: count, dtype: int64

# %%
# Now we can build a table of which comorbidities each patient has ever had
comorbs = clean_df.pivot_table(index="PATNO", columns="CMINDC_TEXT", values="CMINDC",
                               aggfunc=lambda v: 1, fill_value=0)
print(comorbs.shape)
comorbs.head()
# Out:
# (4422, 25)
# CMINDC_TEXT  Anxiety  Atrial Fibrillation / Arrhythmias  \
# PATNO
# 3000               1                                  0
# 3001               0                                  0
# 3002               0                                  0
# 3003               1                                  0
# 3004               0                                  1
#
# CMINDC_TEXT  Benign Prostatic Hypertrophy / Overactive Bladder  \
# PATNO
# 3000                                                         0
# 3001                                                         1
# 3002                                                         0
# 3003                                                         1
# 3004                                                         0
#
# CMINDC_TEXT  Cognitive Dysfunction  Congestive Heart Failure  Constipation  \
# PATNO
# 3000                             0                         0             0
# 3001                             0                         0             1
# 3002                             0                         0             1
# 3003                             0                         0             1
# 3004                             0                         0             0
#
# CMINDC_TEXT  Coronary Artery Disease, Peripheral Artery Disease, Stroke  \
# PATNO
# 3000                                                         0
# 3001                                                         0
# 3002                                                         0
# 3003                                                         0
# 3004                                                         0
#
# CMINDC_TEXT  Daytime Sleepiness  Delusions, Hallucination, Psychosis  \
# PATNO
# 3000                          0                                    0
# 3001                          0                                    0
# 3002                          0                                    0
# 3003                          0                                    0
# 3004                          0                                    0
#
# CMINDC_TEXT  Depression  ...  Nausea  Other  Pain  REM-Behavior Disorder  \
# PATNO                    ...
# 3000                  0  ...       0      1     0                      0
# 3001                  0  ...       0      1     1                      0
# 3002                  0  ...       0      1     1                      0
# 3003                  0  ...       0      1     1                      0
# 3004                  0  ...       0      1     1                      0
#
# CMINDC_TEXT  Restless Leg Syndrome  Sexual Dysfunction  Sialorrhea / Drooling  \
# PATNO
# 3000                             0                   0                      0
# 3001                             0                   0                      0
# 3002                             0                   0                      0
# 3003                             0                   0                      0
# 3004                             0                   0                      0
#
# CMINDC_TEXT  Supplements / Homeopathic Medication  Thyroid Disorder  \
# PATNO
# 3000                                            1                 0
# 3001                                            1                 0
# 3002                                            1                 1
# 3003                                            1                 1
# 3004                                            1                 0
#
# CMINDC_TEXT  Vitamins / Coenzymes
# PATNO
# 3000                            1
# 3001                            0
# 3002                            1
# 3003                            1
# 3004                            1
#
# [5 rows x 25 columns]

# %%
# How many patients have Cognitive Dysfunction? This number is smaller than the one from
# value_counts(), because some patients are given a drug for a comorbidity multiple times
comorbs["Cognitive Dysfunction"].sum()
# Out:
# 112
