# %% [markdown]
# # Exploring Features of Parkinsonism
#
# This notebook shows how to clean and visualize the Features of Parkinsonism data.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pie_clean import *

# %%
# Load and clean data, and check we have Features of Parkinsonism
data = DataLoader.load("../PPMI")
clean_df = data[MEDICAL_HISTORY]["Features_of_Parkinsonism"]
print(clean_df.shape)
clean_df.head()
# Out:
# 2025-10-10 09:15:03 data_loader.py [INFO] Biospecimen modality requested. Exclusion list: []
# 2025-10-10 09:15:03 data_loader.py [INFO] Loading subject_characteristics data...
# 2025-10-10 09:15:03 sub_char_loader.py [INFO] Subject Characteristics: Consolidating rows with duplicate (PATNO, EVENT_ID) pairs. Non-null values for other columns will be pipe-separated if different.
# 2025-10-10 09:15:04 sub_char_loader.py [INFO] Summary of pipe-separated columns for Subject Characteristics:
# 2025-10-10 09:15:04 sub_char_loader.py [INFO]   - Column 'AGE_AT_VISIT': 171 groups had multiple values.
# 2025-10-10 09:15:04 sub_char_loader.py [INFO]     - Example for group ('100232', 'V04'): values were ['65.2', '65.4']
# 2025-10-10 09:15:04 sub_char_loader.py [INFO] Final loaded subject characteristics shape: (36420, 29)
# 2025-10-10 09:15:04 data_loader.py [INFO] Loaded subject_characteristics with 36420 rows
# /Users/vic/Projects/MJFF/PIE-clean/pie_clean/sub_char_loader.py:196: PerformanceWarning: indexing past lexsort depth may impact performance.
#   conflicting_values = df_indexed.loc[first_offending_group_index, col].dropna().astype(str).unique()
# 2025-10-10 09:15:06 data_loader.py [INFO] Loading medical_history data...
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: Adverse_Event
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: AV-133_Prodromal
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: C05-05_PET_Imaging_Substudy
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: Clinical_Diagnosis
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: Clinical_Global_Impression
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: Determination_of_Freezing_and_Falls
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: DPA-714_PET_Imaging_Substudy_Adverse_Event
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: Early_Imaging
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: Features_of_REM_Behavior_Disorder
# 2025-10-10 09:15:06 med_hist_loader.py [WARNING] No CSV file found for prefix: Gait_Substudy_Adverse_Event
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Initiation_of_Dopaminergic_Therapy
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Medical_Conditions
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Neurological_Exam
# /Users/vic/Projects/MJFF/PIE-clean/pie_clean/med_hist_loader.py:142: DtypeWarning: Columns (6,7,13,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pd.read_csv(csv_file)
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Other_Clinical_Features
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Participant_Global_Impression
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: PD_Diagnosis_History
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Pregnancy_Test
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Primary_Clincial_Diagnosis
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Procedure_for_PD_Log
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Report_of_Pregnancy
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: SVA2_PET_Imaging_Substudy
# 2025-10-10 09:15:07 med_hist_loader.py [WARNING] No CSV file found for prefix: Tau_Substudy
# 2025-10-10 09:15:07 data_preprocessor.py [INFO] There are 51 null LEDD values remaining after cleaning
# 2025-10-10 09:15:07 data_preprocessor.py [INFO] There are 78 concomitant medication entries with no start date.
# 2025-10-10 09:15:07 data_preprocessor.py [INFO] There are 21696 concomitant medication entries with no stop date.
# 2025-10-10 09:15:08 data_loader.py [INFO] Loaded 5 medical_history tables
# 2025-10-10 09:15:16 data_loader.py [INFO] Loading motor_assessments data...
# 2025-10-10 09:15:16 data_loader.py [WARNING] Directory not found: ../PPMI/Motor___MDS-UPDRS
# 2025-10-10 09:15:16 data_loader.py [INFO] Loading non_motor_assessments data...
# 2025-10-10 09:15:16 data_loader.py [WARNING] Directory not found: ../PPMI/Non-motor_Assessments
# 2025-10-10 09:15:16 data_loader.py [INFO] Loading biospecimen data...
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No non-batch-corrected Project_151_pQTL_in_CSF files found in ../PPMI/Biospecimen
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded Project_151_pQTL_in_CSF data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No batch-corrected Project_151_pQTL_in_CSF files found in ../PPMI/Biospecimen
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded batch-corrected Project_151_pQTL_in_CSF data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No Metabolomic_Analysis_of_LRRK2 files found in ../PPMI/Biospecimen (excluding CSF files)
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded Metabolomic_Analysis_of_LRRK2 data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No Metabolomic_Analysis_of_LRRK2 files found in ../PPMI/Biospecimen (including CSF files)
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded Metabolomic_Analysis_of_LRRK2_CSF data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No Targeted___untargeted_MS-based_proteomics_of_urine_in_PD files found in ../PPMI/Biospecimen
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded urine proteomics data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No PPMI_Project_9000 files found in ../PPMI/Biospecimen
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded Project 9000 data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No PPMI_Project_222 files found in ../PPMI/Biospecimen
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded Project 222 data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No PPMI_Project_196 files found in ../PPMI/Biospecimen
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded Project 196 data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No PPMI_Project_177 files found in ../PPMI/Biospecimen
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded Project 177 data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [WARNING] No Project_214_Olink files found in ../PPMI/Biospecimen
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loaded Project 214 data: 0 rows
# 2025-10-10 09:15:16 biospecimen_loader.py [INFO] Loading file: ../PPMI/Biospecimen/Current_Biospecimen_Analysis_Results_13Jun2025.csv
# /Users/vic/Projects/MJFF/PIE-clean/pie_clean/biospecimen_loader.py:1296: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# 2025-10-10 09:15:25 biospecimen_loader.py [INFO] Successfully processed Current Biospecimen Analysis data: 9368 rows, 4782 columns
# 2025-10-10 09:15:25 biospecimen_loader.py [INFO] Loaded Current Biospecimen Analysis data: 9368 rows
# 2025-10-10 09:15:25 biospecimen_loader.py [WARNING] No Blood_Chemistry___Hematology files found in ../PPMI/Biospecimen
# 2025-10-10 09:15:25 biospecimen_loader.py [INFO] Loaded Blood Chemistry & Hematology data: 0 rows
# 2025-10-10 09:15:25 biospecimen_loader.py [WARNING] No files matching the provided prefixes found in ../PPMI/Biospecimen
# 2025-10-10 09:15:25 biospecimen_loader.py [INFO] Loaded standard biospecimen files: 0 rows
# 2025-10-10 09:15:25 biospecimen_loader.py [INFO] Using all available data sources
# 2025-10-10 09:15:25 biospecimen_loader.py [INFO] Processing 13 data sources: ['project_151_pQTL_CSF', 'project_151_pQTL_CSF_batch_corrected', 'metabolomic_lrrk2', 'metabolomic_lrrk2_csf', 'urine_proteomics', 'project_9000', 'project_222', 'project_196', 'project_177', 'project_214', 'current_biospecimen', 'blood_chemistry_hematology', 'standard_files']
# 2025-10-10 09:15:25 biospecimen_loader.py [INFO] Memory usage (start of merge_biospecimen_data): 686.65 MB
# 2025-10-10 09:15:25 biospecimen_loader.py [INFO] Merging filtered biospecimen data into a single DataFrame
# 2025-10-10 09:15:26 biospecimen_loader.py [INFO] Created base DataFrame for biospecimen merge with 9368 unique PATNO/EVENT_ID pairs
# 2025-10-10 09:15:26 biospecimen_loader.py [INFO] Memory usage (biospecimen base_df created): 1031.86 MB
# 2025-10-10 09:15:26 biospecimen_loader.py [INFO] Merging current_biospecimen (9368 rows, 4782 total cols) into main biospecimen DataFrame
# 2025-10-10 09:15:28 biospecimen_loader.py [INFO] Memory usage (after merging current_biospecimen): 1279.34 MB
# 2025-10-10 09:15:28 biospecimen_loader.py [INFO] Performing final aggregation on the fully merged biospecimen DataFrame...
# 2025-10-10 09:15:29 biospecimen_loader.py [INFO] Final merged biospecimen DataFrame: 9368 rows, 4782 columns
# 2025-10-10 09:15:29 biospecimen_loader.py [INFO] Confirmed: Final merged biospecimen DataFrame has unique (PATNO, EVENT_ID) pairs.
# 2025-10-10 09:15:29 biospecimen_loader.py [INFO] Data contribution from each source (post-internal aggregation):
# 2025-10-10 09:15:29 biospecimen_loader.py [INFO]   current_biospecimen: 9368 rows, 4780 data columns
# 2025-10-10 09:15:29 biospecimen_loader.py [INFO] Memory usage (end of merge_biospecimen_data (merged)): 1277.66 MB
# 2025-10-10 09:15:30 data_loader.py [INFO] Loaded biospecimen data
# (21787, 12)
#       REC_ID  PATNO EVENT_ID  PAG_NAME   INFODT  FEATBRADY  FEATPOSINS  \
# 0  720683801   3000      V10  DIAGFEAT  03/2015        0.0         0.0
# 1  565128201   3000      V12  DIAGFEAT  04/2016        0.0         0.0
# 2  736287401   3000      V15  DIAGFEAT  03/2019        0.0         0.0
# 3    IA32673   3000      V17    FEATPD  05/2021        0.0         0.0
# 4    IA32676   3001      R18    FEATPD  09/2022        1.0         0.5
#
#    FEATRIGID  FEATTREMOR  PSGLVL ORIG_ENTRY            LAST_UPDATE
# 0        0.0         0.0     NaN    12/2018  2020-06-25 16:02:23.0
# 1        0.0         0.0     NaN    04/2016  2020-06-25 16:02:23.0
# 2        0.0         0.0     NaN    04/2019  2020-06-25 16:02:24.0
# 3        0.0         0.0     5.0    06/2021  2021-06-01 00:00:00.0
# 4        0.5         1.0     1.0    09/2022  2022-09-30 00:00:00.0

# %%
# Cleaning the data mapped Uncertain values in each feature to 0.5
# (half way between No (0) and Yes (1))
print(clean_df.columns.tolist())
clean_df["FEATBRADY"].value_counts()
# Out:
# ['REC_ID', 'PATNO', 'EVENT_ID', 'PAG_NAME', 'INFODT', 'FEATBRADY', 'FEATPOSINS', 'FEATRIGID', 'FEATTREMOR', 'PSGLVL', 'ORIG_ENTRY', 'LAST_UPDATE']
# FEATBRADY
# 1.0    11008
# 0.0    10013
# 0.5      760
# Name: count, dtype: int64

# %%
# Create a count of how many of the features are present
clean_df["Feature count"] = clean_df[
    ["FEATBRADY", "FEATPOSINS", "FEATRIGID", "FEATTREMOR"]].sum(axis=1)
clean_df["Feature count"].value_counts()
# Out:
# Feature count
# 0.0    7797
# 3.0    4246
# 4.0    3817
# 2.0    1827
# 0.5    1769
# 1.0    1251
# 2.5     371
# 1.5     361
# 3.5     348
# Name: count, dtype: int64

# %%
# Plot counts of patients with features at BL and at 2 years (V06)
timepoints = ["BL", "V06"]
sns.countplot(data=clean_df[clean_df["EVENT_ID"].isin(timepoints)], x="Feature count",
              hue="EVENT_ID", hue_order=timepoints)
# Out:
# <Axes: xlabel='Feature count', ylabel='count'>

# %% [markdown]
# We can see that at BL, the overwhelming majority of participants have no features of Parkinsonism (almost 1400 participants). By V06 the majority still have zero features, but the count of those with 3 or 4 features has increased as a proportion of the dataset. This may reflect the difference between PD patients and Healthy Controls.
